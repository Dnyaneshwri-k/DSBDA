# %%
import pandas as pd
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_14508\4080736814.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
import numpy as np

# %%
pd.read_csv('mine.csv')
# Out:
#     math_score  reading_score  writting_score  club_joining_date  placement  \
# 0         69.0           89.0            67.0             2018.0       98.0
# 1         80.0           89.0            64.0             2020.0       87.0
# 2         75.0           90.0            61.0             2020.0       88.0
# 3         72.0           91.0            60.0             2019.0       98.0
# 4         68.0           85.0             NaN             2020.0        NaN
# 5          NaN           86.0            74.0             2019.0       95.0
# 6         68.0           83.0            67.0             2021.0       97.0
# 7         68.0           80.0            69.0             2018.0       99.0
# 8         76.0           94.0            78.0             2020.0       84.0
# 9         60.0           84.0             NaN                NaN       92.0
# 10        67.0           78.0             NaN                NaN       76.0
# ...

# %%
df=pd.read_csv('mine.csv')

# %%
df
# Out:
#     math_score  reading_score  writting_score  club_joining_date  placement  \
# 0         69.0           89.0            67.0             2018.0       98.0
# 1         80.0           89.0            64.0             2020.0       87.0
# 2         75.0           90.0            61.0             2020.0       88.0
# 3         72.0           91.0            60.0             2019.0       98.0
# 4         68.0           85.0             NaN             2020.0        NaN
# 5          NaN           86.0            74.0             2019.0       95.0
# 6         68.0           83.0            67.0             2021.0       97.0
# 7         68.0           80.0            69.0             2018.0       99.0
# 8         76.0           94.0            78.0             2020.0       84.0
# 9         60.0           84.0             NaN                NaN       92.0
# 10        67.0           78.0             NaN                NaN       76.0
# ...

# %%
df.isnull()
# Out:
#     math_score  reading_score  writting_score  club_joining_date  placement  \
# 0        False          False           False              False      False
# 1        False          False           False              False      False
# 2        False          False           False              False      False
# 3        False          False           False              False      False
# 4        False          False            True              False       True
# 5         True          False           False              False      False
# 6        False          False           False              False      False
# 7        False          False           False              False      False
# 8        False          False           False              False      False
# 9        False          False            True               True      False
# 10       False          False            True               True      False
# ...

# %%
df.isnull().sum()
# Out:
# math_score           6
# reading_score        2
# writting_score       4
# club_joining_date    6
# placement            2
# offer_count          2
# gender               5
# region               4
# dtype: int64

# %%
df['math_score']=df['math_score'].fillna(df['math_score'].mode()[0])

# %%
df['reading_score'] = df['reading_score'].fillna(df['reading_score'].mode()[0])

# %%
df['writting_score']=df['writting_score'].fillna(df['writting_score'].mode()[0])

# %%
df['club_joining_date']=df['club_joining_date'].fillna(df['club_joining_date'].mode()[0])
df['placement']=df['placement'].fillna(df['placement'].mode()[0])
df['offer_count']=df['offer_count'].fillna(df['offer_count'].mode()[0])

# %%
df
# Out:
#     math_score  reading_score  writting_score  club_joining_date  placement  \
# 0         69.0           89.0            67.0             2018.0       98.0
# 1         80.0           89.0            64.0             2020.0       87.0
# 2         75.0           90.0            61.0             2020.0       88.0
# 3         72.0           91.0            60.0             2019.0       98.0
# 4         68.0           85.0            61.0             2020.0       80.0
# 5         64.0           86.0            74.0             2019.0       95.0
# 6         68.0           83.0            67.0             2021.0       97.0
# 7         68.0           80.0            69.0             2018.0       99.0
# 8         76.0           94.0            78.0             2020.0       84.0
# 9         60.0           84.0            61.0             2020.0       92.0
# 10        67.0           78.0            61.0             2020.0       76.0
# ...

# %%
df.isnull().sum()
# Out:
# math_score           0
# reading_score        0
# writting_score       0
# club_joining_date    0
# placement            0
# offer_count          0
# gender               5
# region               4
# dtype: int64

# %%
df['gender'].value_counts()
# Out:
# gender
# F    14
# M    11
# Name: count, dtype: int64

# %%
df['gender']=df['gender'].fillna('F')

# %%
df['region'].value_counts()
# Out:
# region
# Pune      9
# Mumbai    7
# Raigad    6
# Nashik    4
# Name: count, dtype: int64

# %%
df['region']=df['region'].fillna('Pune')

# %%
df.isnull().sum()
# Out:
# math_score           0
# reading_score        0
# writting_score       0
# club_joining_date    0
# placement            0
# offer_count          0
# gender               0
# region               0
# dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder

# %%
LE = LabelEncoder()

# %%
col =['math_score','reading_score','writting_score','placement']

# %%
import matplotlib.pyplot as plt
df.boxplot(col)
# Out:
# <Axes: >

# %%
df['Gender'] = LE.fit_transform(df['gender'])

# %%
df.head()
# Out:
#    math_score  reading_score  writting_score  club_joining_date  placement  \
# 0        69.0           89.0            67.0             2018.0       98.0
# 1        80.0           89.0            64.0             2020.0       87.0
# 2        75.0           90.0            61.0             2020.0       88.0
# 3        72.0           91.0            60.0             2019.0       98.0
# 4        68.0           85.0            61.0             2020.0       80.0
#
#    offer_count gender region  Gender
# 0          1.0      M   Pune       1
# 1          3.0      M   Pune       1
# 2          1.0      M   Pune       1
# 3          2.0      F   Pune       0
# 4          2.0      F   Pune       0

# %%
############for finding and correcting outliers##### using Z score

# %%
plt.boxplot(df['reading_score'])
plt.title('BoxPlot')
plt.xlabel('X')
plt.ylabel('Y')
plt.show()

# %%
Q1=df['reading_score'].quantile(0.25)

# %%
Q3=df['reading_score'].quantile(0.75)

# %%
IQR=Q3-Q1

# %%
l=Q1-1.5*IQR

# %%
u=Q3+1.5*IQR

# %%
outliers=[(df['reading_score']<l) | (df['reading_score']>u)]

# %%
print(outliers)
# Out:
# [0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
# Name: reading_score, dtype: bool]

# %%
df
# Out:
#     math_score  reading_score  writting_score  club_joining_date  placement  \
# 0         69.0           89.0            67.0             2018.0       98.0
# 1         80.0           89.0            64.0             2020.0       87.0
# 2         75.0           90.0            61.0             2020.0       88.0
# 3         72.0           91.0            60.0             2019.0       98.0
# 4         68.0           85.0            61.0             2020.0       80.0
# 5         64.0           86.0            74.0             2019.0       95.0
# 6         68.0           83.0            67.0             2021.0       97.0
# 7         68.0           80.0            69.0             2018.0       99.0
# 8         76.0           94.0            78.0             2020.0       84.0
# 9         60.0           84.0            61.0             2020.0       92.0
# 10        67.0           78.0            61.0             2020.0       76.0
# ...

# %%
data=df['math_score']

# %%
data=np.log(data)

# %%
data
# Out:
# 0     4.234107
# 1     4.382027
# 2     4.317488
# 3     4.276666
# 4     4.219508
# 5     4.158883
# 6     4.219508
# 7     4.219508
# 8     4.330733
# 9     4.094345
# 10    4.204693
# 11    4.189655
# 12    4.143135
# 13    4.304065
# 14    4.158883
# 15    4.158883
# 16    4.158883
# 17    4.158883
# 18    4.317488
# 19    4.369448
# 20    4.158883
# 21    4.330733
# 22    4.158883
# 23    4.158883
# 24    4.110874
# 25    4.317488
# 26    4.158883
# 27    4.248495
# 28    4.290459
# 29    4.290459
# Name: math_score, dtype: float64

# %%
data=df['math_score']

# %%
data=np.sqrt(data)

# %%
data
# Out:
# 0     8.306624
# 1     8.944272
# 2     8.660254
# 3     8.485281
# 4     8.246211
# 5     8.000000
# 6     8.246211
# 7     8.246211
# 8     8.717798
# 9     7.745967
# 10    8.185353
# 11    8.124038
# 12    7.937254
# 13    8.602325
# 14    8.000000
# 15    8.000000
# 16    8.000000
# 17    8.000000
# 18    8.660254
# 19    8.888194
# 20    8.000000
# 21    8.717798
# 22    8.000000
# 23    8.000000
# 24    7.810250
# 25    8.660254
# 26    8.000000
# 27    8.366600
# 28    8.544004
# 29    8.544004
# Name: math_score, dtype: float64

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler = MinMaxScaler() #Scaler is object

# %%
df['math_score']=scaler.fit_transform(df[['math_score']])

# %%
df
# Out:
#     math_score  reading_score  writting_score  club_joining_date  placement  \
# 0         0.45           89.0            67.0             2018.0       98.0
# 1         1.00           89.0            64.0             2020.0       87.0
# 2         0.75           90.0            61.0             2020.0       88.0
# 3         0.60           91.0            60.0             2019.0       98.0
# 4         0.40           85.0            61.0             2020.0       80.0
# 5         0.20           86.0            74.0             2019.0       95.0
# 6         0.40           83.0            67.0             2021.0       97.0
# 7         0.40           80.0            69.0             2018.0       99.0
# 8         0.80           94.0            78.0             2020.0       84.0
# 9         0.00           84.0            61.0             2020.0       92.0
# 10        0.35           78.0            61.0             2020.0       76.0
# ...

# %%
scaler1=StandardScaler()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[45], line 1
# ----> 1 scaler1=StandardScaler()
#
# NameError: name 'StandardScaler' is not defined

# %%
df['writting_score']=scaler1.fit_transform(df[['writting_score']])

# %%
df
